# %%
from faster_whisper import WhisperModel
from langchain.llms import Ollama

# %%
model_size = "base"

# %%
model = WhisperModel(model_size, device="cpu", compute_type="int8")

# %%
segments, info = model.transcribe("d&d.mp3", beam_size=5)

# %%
print("Detected language '%s' with probability %f" % (info.language, info.language_probability))
# Out:
# Detected language 'en' with probability 0.994343

# %%
# for segment in segments:
#     print("[%.2fs -> %.2fs] %s" % (segment.start, segment.end, segment.text))

# %%
with open("transcript.txt", "w", encoding="utf-8") as f:
    for i, seg in enumerate(segments):
        f.write(f"[{seg.start:.2f}s → {seg.end:.2f}s] {seg.text.strip()}\n")

# %%
# Loading local LLM 'mistral'
llm = Ollama(model="mistral")
# Out:
# C:\Users\divya\AppData\Local\Temp\ipykernel_33136\72419059.py:2: LangChainDeprecationWarning: The class `Ollama` was deprecated in LangChain 0.3.1 and will be removed in 1.0.0. An updated version of the class exists in the :class:`~langchain-ollama package and should be used instead. To use it run `pip install -U :class:`~langchain-ollama` and import as `from :class:`~langchain_ollama import OllamaLLM``.
#   llm = Ollama(model="mistral")

# %%
# Reading transcript file generated by Whisper Model
with open("transcript.txt", "r", encoding="utf-8") as f:
    lines = [line.strip() for line in f if line.strip()]

# %%
# Function to check if a line is story-relevant
def is_story_relevant(line):
    prompt = f"""You are an AI Dungeon Master assistant.
Decide whether the following sentence from a D&D game is **story-relevant**.
Only reply with "Yes" if it contains character actions, events, NPC interaction, lore, or quests.
Reply "No" to dice rolls, rules, jokes, or out-of-character chatter.

Line: "{line}"
Relevant?"""
    
    result = llm(prompt).strip().lower()
    return result.startswith("yes")

# %%
# Filtering relevant lines
relevant_lines = [line for line in lines if is_story_relevant(line)]
# Out:
# C:\Users\divya\AppData\Local\Temp\ipykernel_33136\3851209369.py:11: LangChainDeprecationWarning: The method `BaseLLM.__call__` was deprecated in langchain-core 0.1.7 and will be removed in 1.0. Use :meth:`~invoke` instead.
#   result = llm(prompt).strip().lower()
# ---------------------------------------------------------------------------
# ConnectionRefusedError                    Traceback (most recent call last)
# File ~\anaconda3\envs\dungeon-scribe\lib\site-packages\urllib3\connection.py:198, in HTTPConnection._new_conn(self)
#     197 try:
# --> 198     sock = connection.create_connection(
#     199         (self._dns_host, self.port),
#     200         self.timeout,
#     201         source_address=self.source_address,
#     202         socket_options=self.socket_options,
#     203     )
#     204 except socket.gaierror as e:
#
# ...

# %%
# Saving relevant lines into a new file
with open("filtered_transcript.txt", "w", encoding="utf-8") as f:
    for line in relevant_lines:
        f.write(line + "\n")
print(f"✅ Filtered {len(relevant_lines)} out of {len(lines)} lines.")
